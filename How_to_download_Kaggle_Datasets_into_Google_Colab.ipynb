# %% [markdown]
# <a href="https://colab.research.google.com/github/kmkarakaya/Deep-Learning-Tutorials/blob/master/How_to_download_Kaggle_Datasets_into_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to download Kaggle Datasets into Google Colab
#
# [Kaggle Dataset is here.](https://www.kaggle.com/savasy/multiclass-classification-data-for-turkish-tc32?select=ticaret-yorum.csv)
#
# [A blog post explaning how to download Kaggle Datasets is here.](https://medium.com/analytics-vidhya/how-to-fetch-kaggle-datasets-into-google-colab-ea682569851a)
#
# My video tutorial explaning how to download Kaggle Datasets is here: [Turkish](https://youtu.be/ls47CPFU1vE)/[English](https://youtu.be/_rlt4mzLDLc)
#
# Colab Notebook: https://colab.research.google.com/drive/1I7UN_1PljB3go4lugJrVEOLP86LnioS7?usp=sharing
#
# GitHub: https://github.com/kmkarakaya/Deep-Learning-Tutorials/blob/master/How_to_download_Kaggle_Datasets_into_Google_Colab.ipynb

# %%
import pandas as pd 
import os

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# gdrive	sample_data

# %% [markdown]
# Get the Kaggle API token (kaggle.json file) from Kaggle and store it to your GDrive folder (e.g. MyDrive/Colab Notebooks/input)

# %% [markdown]
# ![bXKm9bPMbK.gif](data:image/gif;base64,...)

# %%
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/MyDrive/Colab Notebooks/input"

# %%
#changing the working directory
# %cd "/content/gdrive/MyDrive/Colab Notebooks/input"
#Check the present working directory using pwd command
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/input

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/input

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !kaggle datasets download -d savasy/multiclass-classification-data-for-turkish-tc32
# Out:
# ...
#  96% 49.0M/51.3M [00:00<00:00, 65.6MB/s]
# 100% 51.3M/51.3M [00:00<00:00, 80.5MB/s]

# %%
# !ls
# Out:
# 120001_PH1.csv	kaggle.json
# corona.csv	multiclass-classification-data-for-turkish-tc32.zip

# %%
#unzipping the zip files and deleting the zip files
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  multiclass-classification-data-for-turkish-tc32.zip
#   inflating: ticaret-yorum.csv

# %%
# !ls
# Out:
# 120001_PH1.csv	corona.csv  kaggle.json  ticaret-yorum.csv

# %%
data = pd.read_csv('ticaret-yorum.csv')
pd.set_option('max_colwidth', 100)
data.head(5)
# Out:
#     category                                                                                                 text
# 0  alisveris  Altus Hırdavat Yapı Malzemeleri Drone Diye Kargodan Lastik Ayakkabı Çıktı,"Instagram'da dolanırk...
# 1  alisveris  Albay Bilgisayar Garanti Yalanı İle Yanılttı,Garanti kapsamında yer alan  Casper bilgisayarım ga...
# 2  alisveris  Okyanus Petshop Ürün İade Sorunu!,Satıcıdan GittiGidiyor üzerinden 385 TL tutarında Frolicat Int...
# 3  alisveris  Anda İhtiyaç Ve Tüketim Maddeleri Knee Tork Dizlik Esnemiyor!,Anda ihtiyaç ve tüketim maddeleri ...
# 4  alisveris  BB Kargo Dağıtım'dan Aldığım Ürün Bozuk Çıktı Ve Muhatap Bulamıyorum!,Fotoğrafını göndermiş oldu...
