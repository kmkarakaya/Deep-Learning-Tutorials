# %% [markdown]
# <a href="https://colab.research.google.com/github/kmkarakaya/ML_tutorials/blob/master/How_to_upload_an_image_to_Colab_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Use libraries

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-67aef552-2e7d-47b5-be68-9429e34aa969" name="files[]" multiple disabled />
#      <output id="result-67aef552-2e7d-47b5-be68-9429e34aa969">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PartB.png to PartB.png

# %%
Image('PartB.png')

# %%
Image('watch-on-youtube.png', width=100)
