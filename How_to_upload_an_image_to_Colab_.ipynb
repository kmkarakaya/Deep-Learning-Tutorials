# %% [markdown]
# <a href="https://colab.research.google.com/github/kmkarakaya/ML_tutorials/blob/master/How_to_upload_an_image_to_Colab_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #How to upload an image to Colab?

# %% [markdown]
# # Use libraries

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3356ac66-4768-465d-98bc-d644428fdbcc" name="files[]" multiple disabled />
#      <output id="result-3356ac66-4768-465d-98bc-d644428fdbcc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test1.png to test1.png

# %%
Image('test1.png')

# %%
Image('test1.png', width=100)

# %% [markdown]
# # Using interface

# %% [markdown]
# ![My Image](https://github.com/kmkarakaya/ML_tutorials/blob/master/images/test2.png?raw=true)

# %% [markdown]
# # Using html

# %% [markdown]
# <img src="https://github.com/kmkarakaya/ML_tutorials/blob/master/images/test2.png?raw=true:, width=100" alt="My Image" width=200>
